# %% [markdown]
# # all files in the database relating to BAROMETER Pdf has different "File" column pointing to F drive while other pdfs tables have "File" Column pointing to other folder location - corrrect it.

# %%
import  sys
import pathlib
from DataRetreivalController import DataRetreivalController
import os
from backend.db.models import *
import pandas as pd
# %load_ext dotenv
# %reload_ext dotenv
# %dotenv C:\source\2x4_data\app\data\WesternWoodPDFs\westernpdfabstractor\backend\db\.env
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# ProductionUS
# ShipmentUS
# InventoryUS
# OrdersUS
# PPPC
# UnfilledOrdersUS
# ProductionCanada
# ShipmentCanada
# InventoryCanada
# LumberExportCanada
# LogExportUS
# LogImportsUS
# ConsumptionLumberUs
# LumberExportUS
# LumberImportsUS
# ConsumptionLumberCanada
# NorthAmericanProduction
# NorthAmericanShipment
# NorthAmericanOrder
# NorthAmericanUnfiledOrder
# NorthAmericanInventory
# OrdersWestern
# PPPCWestern
# ProductionWestern
# BarometerWestern
# BarometerCoast
# BarometerInland
# BarometerFinishedInventories
# UnfilledOrderWestern
# ShipmentWestern
# InventoryWestern
# ShipmentCoastal
# ShipmentInland
# AveragePriceCoastal
# AveragePriceIsland
# AveragePriceCostalDoglas
# AveragePriceCostalHamfir
# AveragePriceIslandDouglas
# AveragePricePonderasoPine
# AveragePriceWhiteWoods

# %%
List_of_models = [ProductionUS,ShipmentUS,InventoryUS,OrdersUS,PPPC,UnfilledOrdersUS,ProductionCanada,ShipmentCanada,
                 InventoryCanada,LumberExportCanada,LogExportUS,LogImportsUS,ConsumptionLumberUs,LumberExportUS,
                 LumberImportsUS,ConsumptionLumberCanada,NorthAmericanProduction,NorthAmericanShipment,
                 NorthAmericanOrder,NorthAmericanUnfiledOrder,NorthAmericanInventory,OrdersWestern,PPPCWestern,
                 ProductionWestern,BarometerWestern,BarometerCoast,BarometerInland,BarometerFinishedInventories,
                 UnfilledOrderWestern,ShipmentWestern,InventoryWestern,ShipmentCoastal,ShipmentInland,AveragePriceCoastal,
                 AveragePriceIsland,AveragePriceCostalDoglas,AveragePriceCostalHamfir,AveragePriceIslandDouglas,
                 AveragePricePonderasoPine,AveragePriceWhiteWoods]

# %%
# Thes 2 functions required to extract the name of the report from the update table
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

def get_report_name(link):
    link_start = find_nth(link, "\\",8)
    link_end = find_nth(link, "\\",9)
    link_start +=1
    name = link[link_start:link_end]
    return name

# %% [markdown]
# # Check last updated data in the database

# %%
obj=DataRetreivalController()

update_df  = pd.DataFrame(columns=['model','last_updated','Columns','report_name'])

# to_delete_list = []

List_of_error_models=[]
List_of_empty_models=[]

for model in List_of_models:
    
    try:
        data=obj.query_data(model)
        model_data = pd.DataFrame(data)
        max_date = model_data['Timestamp'].max().strftime('%Y-%m-%d')
        columns = model.__table__.columns.keys()
        # .remove('Timestamp') Remove Timestamp from columns list
        model_name = model.__tablename__
        # to_delete_list.append(model_data['File'][0])
        report_name = get_report_name(model_data['File'][0])
        row_data = pd.DataFrame([[model_name,max_date,columns, report_name]],columns=['model','last_updated','Columns','report_name'])
        update_df = pd.concat([update_df, row_data], axis=0)
    except:
        List_of_error_models.append(model.__tablename__)
        print("error in model {}".format(model.__tablename__))
# Out:
# postgresql://fanjum:3cUDV4jctsfF0pYcxoMQ@pg-prod-master.data-191214.com:5432/lumber-data-sources
# wwpa
# Connection Established!
# error in model north_american_inventory

# %% [markdown]
# # error in model north_american_inventory - CHECK WHY?

# %%
update_df
# Out:
#                             model last_updated  \
# 0                   production_us   2022-02-01
# 0                     shipment_us   2022-02-01
# 0                    inventory_us   2022-02-01
# 0                       orders_us   2022-02-01
# 0                            pppc   2022-02-01
# 0               unfilledorders_us   2022-02-01
# 0               production_canada   2022-02-01
# 0                 shipment_canada   2022-02-01
# 0                inventory_canada   2022-02-01
# 0            lumber_export_canada   2022-02-01
# 0                   log_export_us   2022-02-01
# 0                   log_import_us   2022-02-01
# 0           consumption_lumber_us   2022-02-01
# 0                lumber_export_us   2022-02-01
# 0                lumber_import_us   2022-02-01
# 0       consumption_lumber_canada   2022-02-01
# 0       north_american_production   2022-02-01
# 0         north_american_shipment   2022-02-01
# 0            north_american_order   2022-01-01
# 0   north_american_unfilled_order   2022-02-01
# 0                  orders_western   2022-03-01
# 0                    pppc_western   2022-03-01
# 0              production_western   2022-03-01
# 0               barometer_western   2022-05-28
# 0                 barometer_coast   2022-05-28
# 0                barometer_inland   2022-05-28
# 0  barometer_finished_inventories   2022-05-28
# 0          unfilled_order_western   2022-03-01
# 0                shipment_western   2022-03-01
# 0               inventory_western   2022-03-01
# 0                shipment_coastal   2022-03-01
# 0                 shipment_inland   2022-03-01
# 0           average_price_coastal   2022-03-01
# 0            average_price_island   2022-03-01
# 0   average_price_coastal_douglus   2022-03-01
# 0    average_price_coastal_himfir   2022-03-01
# 0    average_price_island_douglas   2022-03-01
# 0    average_price_ponderaso_pine   2022-03-01
# 0       average_price_white_woods   2022-03-01
#
#                                                                                                                                                                            Columns  \
# 0                                                                                                                        [Timestamp, West, South, Other, Total, Year, Month, File]
# 0                                                                                                                        [Timestamp, West, South, Other, Total, Year, Month, File]
# 0                                                                                                                        [Timestamp, West, South, Other, Total, Year, Month, File]
# 0                                                                                                                        [Timestamp, West, South, Other, Total, Year, Month, File]
# 0                                                                       [Timestamp, West, South, Total_US, British_Columbia, East_of_the_Rockies, Total_Canada, Year, Month, File]
# 0                                                                                                                        [Timestamp, West, South, Other, Total, Year, Month, File]
# 0                                                                                                     [Timestamp, British_Columbia, East_of_the_Rockies, Total, Year, Month, File]
# 0                                                                                                     [Timestamp, British_Columbia, East_of_the_Rockies, Total, Year, Month, File]
# 0                                                                                                     [Timestamp, British_Columbia, East_of_the_Rockies, Total, Year, Month, File]
# 0                                                                                                 [Timestamp, To_US,  To_China,  To_Japan, Total_Lumber_Export, Year, Month, File]
# 0                                                                              [Timestamp, To_Canada, To_China, To_Japan, To_Other_Countries, Total_Log_Export, Year, Month, File]
# 0                                                                                             [Timestamp, From_Canada, Non_Canadian_Sources, Total_Log_Imports, Year, Month, File]
# 0                                                                              [Timestamp, Lumber_Shipments, Plus_Imports, Minus_Exports, Apparent_Consumption, Year, Month, File]
# 0                                                             [Timestamp, To_Canada, To_China, To_Japan, 'To_Mexico' , To_Other_Countries, Total_Lumber_Export, Year, Month, File]
# 0                            [Timestamp, From_British_Columbia, East_of_the_Rockies, From_Latin_America, From_Europe, Total_Non_Canadian, Total_Lumber_Imports, Year, Month, File]
# 0                                                                              [Timestamp, Lumber_Shipments, Plus_Imports, Minus_Exports, Apparent_Consumption, Year, Month, File]
# 0  [Timestamp, Coast, Inland, Cal_Coast, Cal_Redwood, South, Other, Total_US, British Columbia, Prairies_And_Eastern_Canada, Total_Canada, Total_North_America, Year, Month, File]
# 0  [Timestamp, Coast, Inland, Cal_Coast, Cal_Redwood, South, Other, Total_US, British Columbia, Prairies_And_Eastern_Canada, Total_Canada, Total_North_America, Year, Month, File]
# 0                                                                        [Timestamp, Coast, Inland, Cal_Coast, Cal_Redwood, Total_West, South, Other, Total_US, Year, Month, File]
# 0                                                                        [Timestamp, Coast, Inland, Cal_Coast, Cal_Redwood, Total_West, South, Other, Total_US, Year, Month, File]
# 0                                                                                                             [Timestamp, Coast, Inland, Cal_RW, Western_Total, Year, Month, File]
# 0                                                                                                             [Timestamp, Coast, Inland, Cal_RW, Western_Total, Year, Month, File]
# 0                                                                                                        [Timestamp, Coast, Inland, Cal_RW, Western_Total, Year, Month, Day, File]
# 0                                                                                        [Timestamp, Production, Orders, Shipments, Unfilled, Inventories, Year, Month, Day, File]
# 0                                                                                        [Timestamp, Production, Orders, Shipments, Unfilled, Inventories, Year, Month, Day, File]
# 0                                                                                        [Timestamp, Production, Orders, Shipments, Unfilled, Inventories, Year, Month, Day, File]
# 0                                                                                                 [Timestamp, Coast_Region, Inland_Region, Western_Totals, Year, Month, Day, File]
# 0                                                                                                             [Timestamp, Coast, Inland, Cal_RW, Western_Total, Year, Month, File]
# 0                                                                                                             [Timestamp, Coast, Inland, Cal_RW, Western_Total, Year, Month, File]
# 0                                                                                                             [Timestamp, Coast, Inland, Cal_RW, Western_Total, Year, Month, File]
# 0                                                                                                           [Timestamp, Northeast, Midwest, South, West, Total, Year, Month, File]
# 0                                                                                                           [Timestamp, Northeast, Midwest, South, West, Total, Year, Month, File]
# 0                                                     [Timestamp, Douglas_Fir_Dry, Douglas_Fir_Green, Douglas_Fir_All, Hem_Fir_Dry, Hem_Fir_Green, Hem_Fir_All, Year, Month, File]
# 0               [Timestamp, Ponderosa_Pine, Douglas_Fir_and_Larch_Dry, Douglas_Fir_and_Larch_Green, White_Fir, Englemann_Spruce, Western_Red_Cedar, Whitewoods, Year, Month, File]
# 0                                                                              [Timestamp, Stand_and_Btr_RL_2x4, Stud_Stand_and_Btr_8_2x4, No2_and_Btr_RL_2x10, Year, Month, File]
# 0                                                                                                        [Timestamp, Stand_and_Btr_RL_2x4, No2_and_Btr_RL_2x10, Year, Month, File]
# 0                                                                                                                  [Timestamp, Stud_8_2x4, No2_and_Btr_RL_2x10, Year, Month, File]
# 0                                                             [Timestamp, Moulding_and_Btr_RW_5_4, No_2_Shop_RW_5_4, No_3_Shop_RW_5_4, No_2_and_Btr_Com_RL_1x6, Year, Month, File]
# 0                                                                                                                           [Timestamp, Stud_8_2x4, Stud_8_2x6, Year, Month, File]
#
#   report_name
# 0   LT1008.pd
# 0   LT1008.pd
# 0   LT1008.pd
# 0   LT1008.pd
# 0   LT1002.pd
# 0   LT1008.pd
# 0   LT1010.pd
# 0   LT1002.pd
# 0   LT1002.pd
# 0   LT1001.pd
# 0   LT1006.pd
# 0   LT1002.pd
# 0   LT1101.pd
# 0   LT1005.pd
# 0   LT1002.pd
# 0   LT1106.pd
# 0   LT1102.pd
# 0   LT1011.pd
# 0   LT1012.pd
# 0   LT1012.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0   Barometer
# 0   Barometer
# 0   Barometer
# 0  01 January
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd
# 0  WLF1001.pd

# %%
update_df.loc[update_df['report_name'] =='westernpdfabstractor','report_name'] = 'Barometer'
update_df.reset_index(drop=True,inplace=True)

# From table name (refer to models column in update dataframe above), get class model name which will be used to fetch information from the database
from backend.db.models import Base
def get_class_by_tablename(table_fullname):
  Base.TBLNAME_TO_CLASS = {}
  for mapper in Base.registry.mappers:
      cls = mapper.class_
      classname = cls.__name__
      if not classname.startswith('_'):
          tblname = cls.__tablename__
          Base.TBLNAME_TO_CLASS[tblname] = cls
  return Base.TBLNAME_TO_CLASS[table_fullname]

# %%
List_of_error_models
# Out:
# ['north_american_inventory']

# %% [markdown]
# # BarometerFinishedInventories is not picking correct data - for report Bar220528.pdf its pulling last column i.e Nov-2021 when it should be pulling first column - i.e April 2022

# %% [markdown]
# # Barometer DATA -
# ### The entire code is to collect all Barometer Data and then join with daily_dataframe in DATA_Aggregation & v2.ipynb

# %%
update_df

# %%
Barometer_list = list(update_df[update_df['report_name'] == 'Barometer']['model'].values)
Barometer_list
# Out:
# ['barometer_western', 'barometer_coast', 'barometer_inland']

# %%
# BarometerFinishedInventories - Note this is Monthly so forward filling it


barometer_data_dict = {}
Barometer_list = list(update_df[update_df['report_name'] == 'Barometer']['model'].values)

df = pd.DataFrame()

for name in Barometer_list:
    model = get_class_by_tablename(name)
    data=obj.query_data(model)
    model_data = pd.DataFrame(data)
    model_data.sort_values(by=['Timestamp'],ascending=False,inplace=True)
    model_data.index = model_data['Timestamp']
    model_data.index = pd.DatetimeIndex(model_data.index)
    model_data.drop(['Timestamp','Month','Day','File','Year'],axis=1,inplace=True)
    barometer_data_dict[model.__tablename__] = model_data

    cols = pd.MultiIndex.from_product([[model.__tablename__], (barometer_data_dict[model.__tablename__].columns)])
    barometer_data_dict[model.__tablename__].columns = cols
    barometer_data_dict[model.__tablename__] = barometer_data_dict[model.__tablename__][~barometer_data_dict[model.__tablename__].index.duplicated(keep='first')]
    df = pd.concat([df, barometer_data_dict[model.__tablename__]], axis=1).fillna(method='ffill').reindex(barometer_data_dict['barometer_western'].index)

df.head(7).append(df.tail(7))
# Out:
# C:\Users\Fanjum_cwp\AppData\Local\Temp\2\ipykernel_7736\2246684819.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.head(7).append(df.tail(7))
#            barometer_western                                         \
#                   Production  Orders Shipments Unfilled Inventories
# Timestamp
# 2022-05-28            264656  255234    263967   547676     1301451
# 2022-05-21            267131  269626    269214   556408     1291480
# 2022-05-14            294908  286652    291002   555996     1320650
# 2022-05-07            298756  294857    295361   542263     1317031
# 2022-04-30            318831  313774    315756   545241     1373162
# 2022-04-23            310446  313162    291287   547223     1280437
# 2022-04-16            310502  309256    302449   527680     1258757
# 2010-02-13            200424  172993    201737   493970      906034
# 2010-02-06            204356  226831    200475   522737      909720
# 2010-01-30            193860  223655    232795   496381      905581
# 2010-01-23            190049  227468    205764   505521      893652
# 2010-01-16            189100  251375    201209   482083      910744
# 2010-01-09            193702  211109    169363   433354      921152
# 2010-01-02            109218  137729    133443   392757      896393
#
#            barometer_coast                                         \
#                 Production  Orders Shipments Unfilled Inventories
# Timestamp
# 2022-05-28          182534  174027    178662   318627      786888
# 2022-05-21          184001  179673    181995   323262      784740
# 2022-05-14          202213  201612    200408   325584      809728
# 2022-05-07          208248  202170    202033   319993      808210
# 2022-04-30          223659  218444    220499   322330      862428
# 2022-04-23          216404  210503    207729   324385      786023
# 2022-04-16          218606  211207    210525   322012      776829
# 2010-02-13          123250  107859    128971   262014      476305
# 2010-02-06          122667  142569    128879   283126      487692
# 2010-01-30          124904  150337    141435   269435      493646
# 2010-01-23          112035  132721    128170   260533      464977
# 2010-01-16          116694  148244    127954   255982      482366
# 2010-01-09          116755  134352    111697   237130      494150
# 2010-01-02           61611   91934     81855   213916      487129
#
#            barometer_inland
#                  Production  Orders Shipments Unfilled Inventories
# Timestamp
# 2022-05-28            82122   81207     85305   229049      514563
# 2022-05-21            83130   89953     87219   233146      506740
# 2022-05-14            92695   85040     90594   230412      510922
# 2022-05-07            90508   92687     93328   222270      508821
# 2022-04-30            95172   95330     95257   222911      510734
# 2022-04-23            94042  102659     83558   222838      494414
# 2022-04-16            91896   98049     91924   205668      481928
# 2010-02-13            77174   65134     72766   231956      429729
# 2010-02-06            81689   84262     71596   239611      422028
# 2010-01-30            68956   73318     91360   226946      411935
# 2010-01-23            78014   94747     77594   244988      428675
# 2010-01-16            72406  103131     73255   226101      428378
# 2010-01-09            76947   76757     57666   196224      427002
# 2010-01-02            47607   45795     51588   178841      409264

# %% [markdown]
# # For Lumber Track - Has Issues with missing data - once done - can join with dailydataframe

# %%
barometer_data_dict = {}
Barometer_list = list(update_df[update_df['report_name'] == 'Lumber Track']['model'].values)

df = pd.DataFrame()

for name in Barometer_list:
    model = get_class_by_tablename(name)
    data=obj.query_data(model)
    model_data = pd.DataFrame(data)
    model_data.sort_values(by=['Timestamp'],ascending=False,inplace=True)
    model_data.index = model_data['Timestamp']
    model_data.index = pd.DatetimeIndex(model_data.index)
    model_data.drop(['Timestamp','Year','Month','File'],axis=1,inplace=True)
    barometer_data_dict[model.__tablename__] = model_data

    cols = pd.MultiIndex.from_product([[model.__tablename__], (barometer_data_dict[model.__tablename__].columns)])
    barometer_data_dict[model.__tablename__].columns = cols
    barometer_data_dict[model.__tablename__] = barometer_data_dict[model.__tablename__][~barometer_data_dict[model.__tablename__].index.duplicated(keep='first')]
    df = pd.concat([df, barometer_data_dict[model.__tablename__]], axis=1)
df.sort_index(ascending=False,inplace=True)

df.head(7).append(df.tail(7))

# %%
lumber_track_tables = df.columns.levels[0]
lumber_track_tables

# %%
col_name = lumber_track_tables[0] 
print(col_name)
df.loc[:,(col_name,)]

# %% [markdown]
# # Important Variables in Lumber Track for daily_dataframe:
# ## whatever table doesn't have a value infront of it - use all columns
#
# 'consumption_lumber_canada':'Apparent_Consumption',
# 'consumption_lumber_us':'Apparent_Consumption',

# %% [markdown]
# # For Western Lumber Facts -
# ## JOIN WITH daily_dataframe - Latest data is lagged by 1 month few days - so April avauilable in early June

# %%
barometer_data_dict = {}
Barometer_list = list(update_df[update_df['report_name'] == 'Western Lumber Facts']['model'].values)

df = pd.DataFrame()

for name in Barometer_list:
    model = get_class_by_tablename(name)
    data=obj.query_data(model)
    model_data = pd.DataFrame(data)
    model_data.sort_values(by=['Timestamp'],ascending=False,inplace=True)
    model_data.index = model_data['Timestamp']
    model_data.index = pd.DatetimeIndex(model_data.index)
    model_data.drop(['Timestamp','Year','Month','File'],axis=1,inplace=True)
    barometer_data_dict[model.__tablename__] = model_data

    cols = pd.MultiIndex.from_product([[model.__tablename__], (barometer_data_dict[model.__tablename__].columns)])
    barometer_data_dict[model.__tablename__].columns = cols
    barometer_data_dict[model.__tablename__] = barometer_data_dict[model.__tablename__][~barometer_data_dict[model.__tablename__].index.duplicated(keep='first')]
    df = pd.concat([df, barometer_data_dict[model.__tablename__]], axis=1)
df.sort_index(ascending=False,inplace=True)

df.head(7).append(df.tail(7))

# %%
western_lumber_facts = df.columns.levels[0]
western_lumber_facts

# %%
col_name = western_lumber_facts[10] 
print(col_name)
df.loc[:,(col_name,)]
